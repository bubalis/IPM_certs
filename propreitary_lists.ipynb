# %%
import tabula
import os
import math

# %%
import PyPDF2

# %%
import camelot

# %%
import shutil

# %%
new_path='/home/bdube/scratch/scratch.pdf'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4c66c87dc2bc> in <module>
# ----> 1 shutil.copy(pdf_path, new_path)
#
# NameError: name 'pdf_path' is not defined

# %%
dir(camelot)
# Out:
# ['PlotMethods',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'core',
#  'format_string',
#  'formatter',
#  'handler',
#  'handlers',
#  'image_processing',
#  'io',
#  'logger',
#  'logging',
#  'parsers',
#  'plot',
#  'plotting',
#  'read_pdf',
#  'utils']

# %%
pdf_path=os.path.join('Already_completed', 'Fair_Trade_intl_SPO_EN.pdf'
)

# %%
chem_list= []
for p in range(58, 80):
    tables = camelot.read_pdf(pdf_path, pages=str(p))
    if not 'Red List' in tables[0].df.loc[0,0]:
        break
    else:
        chem_list+=tables[0].df.drop([0,1])[1].tolist()

        
with open(os.path.join('pesticide_lists', 'fair_trade_intl_banned.txt'), 'w+') as file:
    print('\n'.join([c.replace('\n', '') for c in chem_list]), file = file)

# %%
chem_list= []
for p in range(67, 70):
    print(p)
    tables = camelot.read_pdf(pdf_path, pages=str(p))
    df =  tables[0].df
    print(df.loc[0,0])
    if  'Red List' in df.loc[0,0]:
        continue
    elif 'Orange List' in df.loc[0,0]:
        chem_list+=df.drop([0,1])[1].tolist()
    else:
        break

print(chem_list)
        
with open(os.path.join('pesticide_lists', 'fair_trade_intl_restricted.txt'), 'w+') as file:
    print('\n'.join([c.replace('\n', '') for c in chem_list]), file = file)
# Out:
# 67
# Orange List (Restricted List)
# 68
# Orange List (Restricted List)
# 69
# Yellow List (Flagged List)
# ['2,4-DB', 'Abamectin', 'Acetamiprid', 'Aluminum phosphide', 'Amisulbrom', 'Amitraz', 'Atrazine', 'Beta –cyfluthrin', 'Bifenthrin', 'Carbaryl', 'Carbendazim', 'Chlorantraniliprole,', 'Chlorothalonil', 'Chlorpyrifos, \nChlorpyrifos-methyl', 'Clothianidin', 'Cypermethrin & its \nalpha and beta \nisomer', 'Deltamethrin', 'Dimethoate', 'Epoxiconazole', 'Etofenprox', 'Fenitrothion', 'Flufenoxuron', 'Fipronil', 'Flusilazole', 'Glyphosate and its \nsalts', 'Glufosinate \nammonium', 'Imidacloprid', 'Lambda-cyhalothin', 'Lufenuron', 'Mancozeb', 'Oxamyl', 'Phosphine', 'Pirimicarb', 'Procymidone', 'Propargite', 'Quinoxyfen', 'Sulfoxaflor', 'Thiacloprid', 'Thiamethoxam']

# %%
import re

# %%
page=reader.getPage(58)
#names=[i for i in re.split('YES', page.extractText())]

# %%
page.extractText().split('\n')
# Out:
# [' ',
#  ' ',
#  '6',
#  ' ',
#  ' ',
#  'Pesticide',
#  ' ',
#  'CAS number',
#  ' ',
#  'WH',
#  'O Ia',
#  ' ',
#  'WH',
#  'O Ib',
#  ' ',
#  'GHS ',
#  'Cance',
#  'r   1A  ',
#  '1B',
#  ' ',
#  'GHS ',
#  'muta  ',
#  '1A  ',
#  '1B',
#  ' ',
#  'GHS ',
#  'repr',
#  'o  1A ',
#  '1B',
#  ' ',
#  'Mont',
#  '-',
#  'real ',
#  'Proto',
#  '-',
#  'col',
#  ' ',
#  'Rotter',
#  '-',
#  'dam ',
#  'Conven',
#  '-',
#  'tion',
#  ' ',
#  'Stock',
#  '-',
#  'holm ',
#  'Conven',
#  '-',
#  'tion',
#  ' ',
#  'Severe ',
#  'Effects',
#  ' ',
#  '34)',
#  ' ',
#  'Coumatetralyl',
#  ' ',
#  '5836',
#  '-',
#  '29',
#  '-',
#  '3',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '35)',
#  ' ',
#  'Creosote',
#  ' ',
#  '8001',
#  '-',
#  '58',
#  '-',
#  '9',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '36)',
#  ' ',
#  'DDT',
#  ' ',
#  '50',
#  '-',
#  '29',
#  '-',
#  '3',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  '37)',
#  ' ',
#  'Demeton',
#  '-',
#  'S',
#  '-',
#  'methyl',
#  ' ',
#  '919',
#  '-',
#  '86',
#  '-',
#  '8',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '38)',
#  ' ',
#  'Dichlorvos; DDVP',
#  ' ',
#  '62',
#  '-',
#  '73',
#  '-',
#  '7',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '39)',
#  ' ',
#  'Dicrotophos',
#  ' ',
#  '141',
#  '-',
#  '66',
#  '-',
#  '2',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '40)',
#  ' ',
#  'Difenacoum',
#  ' ',
#  '56073',
#  '-',
#  '07',
#  '-',
#  '5',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '41)',
#  ' ',
#  'Difethialone',
#  ' ',
#  '104653',
#  '-',
#  '34',
#  '-',
#  '1',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '42)',
#  ' ',
#  'Dinocap',
#  ' ',
#  '39300',
#  '-',
#  '45',
#  '-',
#  '3',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '43)',
#  ' ',
#  'Dinoterb',
#  ' ',
#  '1420',
#  '-',
#  '07',
#  '-',
#  '1',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '44)',
#  ' ',
#  'Diphacinone',
#  ' ',
#  '82',
#  '-',
#  '66',
#  '-',
#  '6',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '45)',
#  ' ',
#  'Disulfoton',
#  ' ',
#  '298',
#  '-',
#  '04',
#  '-',
#  '4',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '46)',
#  ' ',
#  'DNOC and its salts',
#  ' ',
#  '534',
#  '-',
#  '52',
#  '-',
#  '1',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  '47)',
#  ' ',
#  'Edifenphos',
#  ' ',
#  '17109',
#  '-',
#  '49',
#  '-',
#  '8',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '48)',
#  ' ',
#  'Endosulfan',
#  ' ',
#  '115',
#  '-',
#  '29',
#  '-',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  '49)',
#  ' ',
#  'Endosulfan I (alpha)',
#  ' ',
#  '959',
#  '-',
#  '98',
#  '-',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  '50)',
#  ' ',
#  'E',
#  '-',
#  'Phosphamidon',
#  ' ',
#  '297',
#  '-',
#  '99',
#  '-',
#  '4',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '51)',
#  ' ',
#  'Epichlorohydrin',
#  ' ',
#  '106',
#  '-',
#  '89',
#  '-',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '52)',
#  ' ',
#  'EPN',
#  ' ',
#  '2104',
#  '-',
#  '64',
#  '-',
#  '5',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '53)',
#  ' ',
#  'Epoxiconazole',
#  ' ',
#  '133855',
#  '-',
#  '98',
#  '-',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '54)',
#  ' ',
#  'Ethiofencarb',
#  ' ',
#  '29973',
#  '-',
#  '13',
#  '-',
#  '5',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '55)',
#  ' ',
#  'Ethoprophos; Ethoprop',
#  ' ',
#  '13194',
#  '-',
#  '48',
#  '-',
#  '4',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '56)',
#  ' ',
#  'Ethylene dibromide; ',
#  '1,2',
#  '-',
#  'dibromoethane',
#  ' ',
#  '106',
#  '-',
#  '93',
#  '-',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  '57)',
#  ' ',
#  'Ethylene dichloride; 1,2',
#  '-',
#  'Dichloroethane',
#  ' ',
#  '107',
#  '-',
#  '06',
#  '-',
#  '2',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  '58)',
#  ' ',
#  'Ethylene oxide',
#  ' ',
#  '75',
#  '-',
#  '21',
#  '-',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  '59)',
#  ' ',
#  'Ethylene thiourea',
#  ' ',
#  '9',
#  '6',
#  '-',
#  '45',
#  '-',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '60)',
#  ' ',
#  'Famphur',
#  ' ',
#  '52',
#  '-',
#  '85',
#  '-',
#  '7',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '61)',
#  ' ',
#  'Fenamiphos',
#  ' ',
#  '22224',
#  '-',
#  '92',
#  '-',
#  '6',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '62)',
#  ' ',
#  'Fenchlorazole',
#  '-',
#  'ethyl',
#  ' ',
#  '103112',
#  '-',
#  '35',
#  '-',
#  '2',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '63)',
#  ' ',
#  'F',
#  'ipronil',
#  ' ',
#  '120068',
#  '-',
#  '37',
#  '-',
#  '3',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  '64)',
#  ' ',
#  'Flocoumafen',
#  ' ',
#  '90035',
#  '-',
#  '08',
#  '-',
#  '8',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '65)',
#  ' ',
#  'Fluazifop',
#  '-',
#  'butyl',
#  ' ',
#  '69806',
#  '-',
#  '50',
#  '-',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '66)',
#  ' ',
#  'Flucythrinate',
#  ' ',
#  '70124',
#  '-',
#  '77',
#  '-',
#  '5',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '67)',
#  ' ',
#  'Flumioxazin',
#  ' ',
#  '103361',
#  '-',
#  '09',
#  '-',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '68)',
#  ' ',
#  'Fluoroacetamide',
#  ' ',
#  '640',
#  '-',
#  '19',
#  '-',
#  '7',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  '69)',
#  ' ',
#  'Flusilazole',
#  ' ',
#  '85509',
#  '-',
#  '19',
#  '-',
#  '9',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '70)',
#  ' ',
#  'Formetanate',
#  ' ',
#  '22259',
#  '-',
#  '30',
#  '-',
#  '9',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '71)',
#  ' ',
#  'Furathiocarb',
#  ' ',
#  '65907',
#  '-',
#  '30',
#  '-',
#  '4',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '72)',
#  ' ',
#  'Glufosinate',
#  '-',
#  'ammonium',
#  ' ',
#  '77182',
#  '-',
#  '82',
#  '-',
#  '2',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '73)',
#  ' ',
#  'Heptenophos',
#  ' ',
#  '23560',
#  '-',
#  '59',
#  '-',
#  '0',
#  ' ',
#  ' ',
#  '',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '']

# %%
'\nInsecticides:   \n        \n\n\n\nDisulfoton (Disyston)    \n\n\nHerbicides: May Use with Restriction:Insecticides:All  Insecticides* : See protocols on page 22 for resistance managment strategies.\n harvest (maximum of 2 pints per season)  Apply only as needed when wireworms or other soil in-sects are expected to be present. Herbicides:   \n\n\n'
# Out:
# '\nInsecticides:   \n        \n\n\n\nDisulfoton (Disyston)    \n\n\nHerbicides: May Use with Restriction:Insecticides:All  Insecticides* : See protocols on page 22 for resistance managment strategies.\n harvest (maximum of 2 pints per season)  Apply only as needed when wireworms or other soil in-sects are expected to be present. Herbicides:   \n\n\n'

# %%
names=[n.replace('\n', '').strip() for n in names[1:] if n]

# %%
text=re.split()

# %%
names=[n.replace('\n', '').strip() for n in names[1:] if n]

# %%
print('\n'.join(names))
# Out:
# Oxydemeton Methyl
# Parathion Ethyl
# Pentachlorophenol
# Phorate
# Phosmet
# Phosphine
# Profenofos
# Propetamphos
# Resmethrin
# Sumithrin (phenothrin)
# Thiacloprid
# Thiamethoxam
# Thiazopyr

# %%
regex='|'.join(names)
text=re.split(regex, page.extractText())

# %%
text
# Out:
# [' BloomCheck Standard Version 2.0, June 2019\n           33 of 34\n Allethrin\n YES  Amitrole\n  YES Azinphos methyl\n YES  ',
#  None,
#  None,
#  '\n  YES ',
#  None,
#  None,
#  '\n  YES ',
#  None,
#  None,
#  '\n  YES ',
#  None,
#  None,
#  '\n  YES ',
#  None,
#  None,
#  '\n  YES ',
#  None,
#  None,
#  '\n YES  ',
#  None,
#  None,
#  '\n  YES ',
#  None,
#  None,
#  ' methyl\n  YES ',
#  None,
#  None,
#  '\n  YES Demeton (Demeton \nS-Methyl)\n YES  ',
#  None,
#  None,
#  '\n  YES Dichlorvos (DDVP)\n YES  ',
#  None,
#  None,
#  '\n  YES ',
#  None,
#  None,
#  '\n  YES ',
#  None,
#  None,
#  '\n YES  ',
#  None,
#  None,
#  '\n YES  ',
#  None,
#  None,
#  '\n YES  ',
#  None,
#  None,
#  '\n  YES ',
#  None,
#  None,
#  '\n  YES ',
#  None,
#  None,
#  '\n YES  ',
#  None,
#  None,
#  ' \n  YES ',
#  None,
#  None,
#  '\n YES  ',
#  None,
#  None,
#  '\n  YES ',
#  None,
#  None,
#  '\n YES  ',
#  None,
#  None,
#  '\n YES  ',
#  None,
#  None,
#  '\n YES  ',
#  None,
#  None,
#  '\n YES  ',
#  None,
#  None,
#  '\n YES  ',
#  None,
#  None,
#  '\n YES  ']

# %%
import tabula
import os
import math

# %%
os.chdir("Cert_standards")

# %%
tabula.read_pdf?

# %%
pdf_path="TruEarth-Protocol-and-Self-Assessment-2020-.pdf"

# %%
dfs=tabula.read_pdf(pdf_path, pages='all')

# %%
dfs=dfs[::-1]

# %%
results=[]
for df in dfs:
    if 'DO NOT USE' in df.columns:
        results+=df['Unnamed: 0'].tolist()
    else:
        break

# %%
results=[i for i in results if (i!='Active Ingredient' and str(i)!='nan')]

# %%
with open('TRUEarth_banned.txt', 'w+') as file:
    print('\n'.join(results), file=file)

# %%
df['USE WITH RESTRICTIONS (MODERATE to HIGH-RISK PESTICIDES), RESTRICTIONS WHICH EXCEED THE PRODUCT LABEL']
# Out:
# 0     Trade Name Active Ingredient Concerns  Trueart...
# 1                                       Weed Management
# 2     Gramoxone paraquat dichloride acute toxicity t...
# 3        groundwater contaminant, with an enclosed cab.
# 4                             moderate aquatic toxicity
# 5     Select clethodim potential groundwater contami...
# 6                                 (CAUTION label) only.
# 7     Sinbar  terbacil developmental toxin, potentia...
# 8                        groundwater contaminant season
# 9     2,4-D 2,4-D acute toxicity to workers, possibl...
# 10                            carcinogen between labels
# 11                                                Other
# 12    DPA, No Scald, diphenylamine acute toxicity to...
# 13                  Shield be used as drenches, sprays,
# 14                        flooding, fogging or aerosol.
# 15                     2. DANGER label formulations may
# 16                           only be used as fogging or
# 17                       aerosol by custom applicators.
# 18    Ethephon ethephon toxic to bees, toxic to eart...
# 19                                            thinning.
# 20                  2. Use for fruit ripening only when
# 21                       directed by the packing house.
# 22    Sevin carbaryl extremely toxic to aquatic Appl...
# 23                  invertebrates, highly toxic to bees
# Name: USE WITH RESTRICTIONS (MODERATE to HIGH-RISK PESTICIDES), RESTRICTIONS WHICH EXCEED THE PRODUCT LABEL, dtype: object

# %%
prohibited
# Out:
# [nan,
#  '2,4,5-T and its salts and esters',
#  'Alachlor',
#  'Aldicarb',
#  'Aldrin',
#  'Alpha-BHC; Alpha-HCH',
#  'Azinphos-methyl',
#  'Beta hexachlorocyclohexane',
#  'Binapacryl',
#  '†Brodifacoum',
#  '†Bromadiolone',
#  'Bromethalin',
#  'Calcium cyanide',
#  'Captafol',
#  'Chlordane',
#  'Chlordecone',
#  'Chlordimeform',
#  'Chlorethoxyphos',
#  'Chlormephos',
#  'Chlorobenzilate',
#  'Chlorophacinone',
#  'DDT',
#  'Dieldrin',
#  'Difenacoum',
#  'Difethialone',
#  'Dinoseb and its salts and esters',
#  'Diphacinone',
#  'Disulfoton',
#  'DNOC (Dinitro-ortho-cresol) and its salts*',
#  nan,
#  'Parathion-methyl, Methyl-parathion',
#  'Pentachlorobenzene',
#  'Pentachlorophenol and its salts and esters',
#  'Perfluorooctane sulfonic acid, its salts and',
#  nan,
#  'perfluorooctane sulfonyl fluoride',
#  'Phenylmercury acetate',
#  'Phorate',
#  'Phosphamidon (including E and Z)',
#  'Polychlorinated biphenyls (PCB)',
#  'Polychlorinated naphthalenes',
#  'Sodium Fluoroacetate',
#  'Sulfotep',
#  'Tebupirimifos',
#  'Terbufos',
#  'Tetrabromodiphenyl ether and pentabromodiphenyl',
#  nan,
#  'ether',
#  'Toxaphene (Camphechlor)',
#  'Tributyltin compounds*']

# %%
prohibited=[i for i in prohibited if isinstance(i, str)]
with open('FTUSA_banned.txt', 'w+') as file:
    print('\n'.join(prohibited), file=file)

# %%
import os

# %%
restricted=[]
for df in dfs:
    try:
        items=df['Unnamed: 0'].tolist()
    except:
        continue
    if items:
        if items[0]=='Restricted Active Ingredient':
            restricted+=items[1:]

# %%
restricted=[i for i in restricted if isinstance(i, str)]
with open('FTUSA_restricted.txt', 'w+') as file:
    print('\n'.join(restricted), file=file)

# %%
os.chdir(r"C:\Users\benja\Documents\UVM\Dissertation_Docs\Cert_standards")

# %%
import camelot

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-2472745b4898> in <module>
#       1 import camelot
# ----> 2 tables = camelot.read_pdf('foo.pdf')
#
# AttributeError: module 'camelot' has no attribute 'read_pdf'

# %%
with open('eco_apple_banned.txt', 'w+') as file:
    text='\n'.join([str(a) for a in dfs[-1]['Unnamed: 0'].to_list()])
    print(text, file=file)
    print('\n', file=file)
    text='\n'.join([str(a) for a in dfs[-2]['Unnamed: 0'].to_list()])
    print(text, file=file)

# %%
with open('eco_apple_restricted.txt', 'w+') as file:
    for i in range(-8, -2):
        text='\n'.join([str(a) for a in dfs[-1]['Unnamed: 0'].to_list()])
        print(text, file=file)
        print('\n', file=file)

# %%
dfs=[]
for i in range(1, 44):
    dfs.append(tabula.read_pdf(pdf_path, pages=[i], lattice=True))

# %%
dfs=[d for d in dfs if len(d)>0]

# %%
other_df=tabula.read_pdf(pdf_path, pages=[28], lattice=True)

# %%
other_df[1]
# Out:
#    USE WITH RESTRICTIONS (MODERATE to HIGH-RISK PESTICIDES), RESTRICTIONS WHICH EXCEED THE PRODUCT LABEL\r1.These pesticides have additional restrictions which supersede the pesticide label to mitigate moderate to high risks to environmental and\rhuman health.\r2.Use with justification and only when less hazardous alternatives (e.g., those listed above) are not adequate.\r3.Use only after systematic scouting or weather monitoring and science-based thresholds, or according to previous history where thresholds are\rnot available.\r4.Pesticides included are not a guarantee of efficacy.  Some products will not be as effective as other products against specific target pests.  \
# 0                                          Trade Name
# 1                              Insect/Mite Management
# 2           Insecticide-coated\rapple maggot\rspheres
# 3                                             Altacor
# 4                                         Delegate WG
# 5                                              Exirel
# 6                                             Lorsban
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                   Verdepryn 100 SL
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                             Versys
#
#              Unnamed: 0                                         Unnamed: 1  \
# 0     Active Ingredient                                           Concerns
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3   chlorantraniliprole  toxic to aquatic organisms\rand certain benefi...
# 4            spinetoram     toxic to bees, toxic to aquatic\rinvertebrates
# 5      cyantraniliprole  highly toxic to bees, toxic to\raquatic invert...
# 6                Lorsba                                       chlorpyrifos
# 7                   NaN                                                NaN
# 8                   NaN                                                NaN
# 9                   NaN                                                NaN
# 10                  NaN                                                NaN
# 11                  NaN                                                NaN
# 12                  NaN                                                NaN
# 13                  NaN                                                NaN
# 14                  NaN                                                NaN
# 15      Verdepryn 100 S                                     cyclaniliprole
# 16                  NaN                                       invertebrate
# 17                  NaN                                                NaN
# 18                  NaN                                                NaN
# 19         afidopyropen             Toxic to bees, acute-aquatic\rtoxicity
#
#                                            Unnamed: 2  \
# 0                               Truearth Restrictions
# 1                                                 NaN
# 2   Insecticide-coated spheres may only\rbe used t...
# 3   Do not expose more than one\rgeneration of the...
# 4   Do not expose more than one\rgeneration of the...
# 5   1.Do not apply until after bloom.\r2.Do not ex...
# 6                                         chlorpyrifo
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                     cyclaniliprole
# 16                         Do not expose more than on
# 17                   generation of the target pest to
# 18                          this mode of action alone
# 19                    Do not apply until after bloom.
#
#                                            Unnamed: 3  \
# 0                                       Best Practice
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   acute toxicity to workers,\rcholinesterase inh...
# 7                           cholinesterase inhibitor,
# 8                                  suspected endocrin
# 9                           disruptor, broad spectrum
# 10                                highly toxic to bee
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15     toxic to bees, toxic to aquatic\rinvertebrates
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                             Unnamed: 4  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6            acute toxicity to workers
# 7       2.Apply only as a trunk spray.
# 8   Note: Label for trunk applications
# 9               only allows post-bloom
# 10     applications, prohibits contact
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15     toxic to bees, toxic to aquatic
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
#
#                                            Unnamed: 5  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   1.Use for trunk borer species only.\r2.Apply o...
# 7                         sprayer may be used to appl
# 8                      the trunk application.  Review
# 9                               issues that should be
# 10                       considered before using this
# 11                 with fruit and foliage and require
# 12                      application using hand wand o
# 13                                   shielded sprayer
# 14                                                NaN
# 15  1.Do not apply until after bloom.\rDo not expo...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                              Unnamed: 6            Unnamed: 7  \
# 0                                   NaN                   NaN
# 1                                   NaN                   NaN
# 2                                   NaN                   NaN
# 3                                   NaN                   NaN
# 4                                   NaN                   NaN
# 5                                   NaN                   NaN
# 6   1.Use for trunk borer species only.                   NaN
# 7                                   NaN                   NaN
# 8                                   NaN                   NaN
# 9                                   NaN                   NaN
# 10                                  NaN                   NaN
# 11                             strategy                   NaN
# 12        http://cotton.tamu.edu/Weeds/                   NaN
# 13           leaning%20Field%20Sprayers                   NaN
# 14                                  NaN  pdf identifies these
# 15      .Do not apply until after bloom                   NaN
# 16                                  NaN                   NaN
# 17                                  NaN                   NaN
# 18                                  NaN                   NaN
# 19                                  NaN                   NaN
#
#                        Unnamed: 8
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6   A carefully cleaned herbicide
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                            NaN

# %%
results=[other_df[2].columns[0]]

# %%
results.append('cyclaniliprole')

# %%
results+=other_df[1]['Unnamed: 0'].tolist()

# %%
other_dfs=tabula.read_pdf(pdf_path, pages=[31], lattice=True)

# %%
results+=other_dfs[1]["Unnamed: 0"].tolist()

# %%
results.append('mefentrifluconazole')

# %%
other_dfs[1]
# Out:
#    USE WITH RESTRICTIONS (MODERATE to HIGH-RISK PESTICIDES), RESTRICTIONS WHICH EXCEED THE PRODUCT LABEL  \
# 0                                          Trade Name
# 1                                  Disease Management
# 2                                 Strobilurins (QoIs)
# 3                                               Flint
# 4                                            Pristine
# 5                                              Sovran
# 6                            Sterol inhibitors (DMIs)
# 7                                               Ceyva
# 8                                                 NaN
# 9                                            Indar 2F
# 10                                                NaN
# 11              2.May be used alone within 30 days of
# 12                                                NaN
# 13                 arvest, however, must be tank mixe
# 14            ith a protectant if active scab lesions
# 15                 re present at time of application.
#
#                    Unnamed: 0  \
# 0           Active Ingredient
# 1                         NaN
# 2                         NaN
# 3             trifloxystrobin
# 4   boscalid,\rpyraclostrobin
# 5             kresoxim-methyl
# 6                         NaN
# 7                        Ceyv
# 8                         NaN
# 9               fenbuconazole
# 10            Do not use wher
# 11                        NaN
# 12        resistance is known
# 13                        NaN
# 14                        NaN
# 15                        NaN
#
#                                            Unnamed: 1  \
# 0                                            Concerns
# 1                                                 NaN
# 2                                                 NaN
# 3   toxic to fish and aquatic\rinvertebrates, poss...
# 4   possible carcinogen, toxic\rto fish and aquati...
# 5   likely carcinogen,\rsuspected groundwater\rcon...
# 6                                                 NaN
# 7                                 mefentrifluconazole
# 8                               nvertebrates and fish
# 9   toxic to fish, aquatic\rinvertebrates, algae, ...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                                            Unnamed: 2  \
# 0                               Truearth Restrictions
# 1                                                 NaN
# 2                                                 NaN
# 3   1.Must be tank mixed with a protectant\rfungic...
# 4   1.Must be tank mixed with a protectant\rfungic...
# 5   1.Must be tank mixed with a protectant\rfungic...
# 6                                                 NaN
# 7                                  mefentrifluconazol
# 8               1.Must be tank mixed with a protectan
# 9                                            ungicide
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                                            Unnamed: 3             Unnamed: 4  \
# 0                                       Best Practice                    NaN
# 1                                                 NaN                    NaN
# 2                                                 NaN                    NaN
# 3   Recommended to tank mix\rwith captan if bitter...                    NaN
# 4   1.Use only in rotation with a\rdifferent mode ...                    NaN
# 5   Recommended to tank mix\rwith captan if bitter...                    NaN
# 6                                                 NaN                    NaN
# 7                                                 NaN  oxic to algae, aquati
# 8                                                 NaN                    NaN
# 9                                                 NaN                    NaN
# 10                                                NaN                    NaN
# 11                                                NaN                    NaN
# 12                                                NaN                    NaN
# 13                                                NaN                    NaN
# 14                                                NaN                    NaN
# 15                                                NaN                    NaN
#
#     Unnamed: 5                                         Unnamed: 6  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN  1.Must be tank mixed with a protectant\rfungic...
# 8          NaN                                                NaN
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# 13         NaN                                                NaN
# 14         NaN                                                NaN
# 15         NaN                                                NaN
#
#                                 Unnamed: 7
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7   Do not use where\rresistance is known.
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN

# %%
dfs_to_keep=[]
for df_list in dfs:
    if any(['USE WITH RESTRICTIONS' in col for col in df_list[0].columns]):
        dfs_to_keep += df_list
    elif 'Lorsban'== df_list[0].colums[0]:
        dfs_to_keep.append()
        print(df_list[0].columns)
# Out:
# Index(['Block ID', 'Cultivars', 'Acres', 'Unnamed: 0', 'Annual Production',
#        'Unnamed: 1'],
#       dtype='object')
# Index(['Legal Requirements'], dtype='object')
# Index(['Soil and Water Conservation'], dtype='object')
# Index(['9', 'Unnamed: 0',
#        'Are pesticide and nutrient application equipment calibrated\raccording to the manufacturer’s instructions, at least annually? S',
#        '•Procedures, results, adjustments made and name of\rindividual who performed the most recent calibration are\ravailable for inspection.\r•Airblast sprayer calibration verifies gallon per acre (GPA)\rapplication rates by documenting travel-ground speed,\rgallon-per-minute flow rates of nozzles, sprayer pressure\rand tree-row widths.\r•Spray control systems including GPS and flow meters are\rcalibrated during initial installation and inspected annually for\rmaintenance needs and recalibrated when necessary, e.g.,\rafter parts replacement.\r•Growers contracting with custom applicators should request\rverification that equipment is calibrated.\r•Calibration for airblast sprayer:\rextension.psu.edu/sprayer-calibration-information\rsprayers101.com/airblast-output\rsprayers101.com/how-to-calibrate-an-airblast-sprayer-\roperator\r•Calibration for boom sprayer:\rextension.colostate.edu/docs/pubs/farmmgt/05003.pdf\r•Calibration for rotary spreader:\rpesticidestewardship.org/calibration/Pages/RotarySpreader.\raspx\r•Calibration for a drop spreader:\rpesticidestewardship.org/homeowner/how-to-calibrate-a-\rdrop-spreader\r•Note: Tree-row volume is helpful in determining the\rappropriate GPA of water based on tree size, canopy density\rand row width.',
#        'Unnamed: 1'],
#       dtype='object')
# Index(['Pest Monitoring and Management'], dtype='object')
# Index(['16', 'Unnamed: 0',
#        'Are pesticide application decisions and timing based on data from\rthe farm and techniques such as action thresholds, degree-day\rmodels and decision-support/ predictive systems? D',
#        '•Where available and recommended by Extension or\rother regional experts, action thresholds are used to\rdetermine whether or not and when to take action\ragainst pests, e.g., codling moth, apple maggot, plum\rcurculio and apple scab.\r•Where recommended, models are used to estimate\rwhen pests or diseases will require treatment, e.g.,\raccumulation of degree days from a codling moth biofix,\rapple scab infections, or exceeding threshold on traps,\re.g., five apple maggots caught on a baited sphere.',
#        'Unnamed: 1'],
#       dtype='object')
# Index(['Food Safety and Product Quality'], dtype='object')
# Index(['Soil and Water Conservation'], dtype='object')
# Index(['Pesticide Use and Hazard Reduction', 'Unnamed: 0', 'Unnamed: 1',
#        'Unnamed: 2'],
#       dtype='object')
# Index(['48', '1', 'Unnamed: 0',
#        'Is pollination accomplished without commercially produced bumblebee hives? S'],
#       dtype='object')
# Index(['54', '1', 'Unnamed: 0',
#        'Are grain-based rodenticides (corn, oats) only applied in bait stations or burrows? D\r\rNote: Rodenticide applications are included on spray records and include date and blocks treated.  Including a rate\rper acre is not necessary.',
#        'Unnamed: 1'],
#       dtype='object')
# Index(['Pest Monitoring and Management'], dtype='object')
# Index(['Orchard Floor, Weed and Alternate-Host Management'], dtype='object')
# Index(['Grower Education and Self-Improvement'], dtype='object')
# Index(['Energy and Waste Conservation', 'Unnamed: 0', 'Unnamed: 1',
#        'Unnamed: 2'],
#       dtype='object')
# Index(['Food Safety and Product Quality', 'Unnamed: 0', 'Unnamed: 1',
#        'Unnamed: 2'],
#       dtype='object')
# Index(['SCORE CARD'], dtype='object')
# Index(['Mating disruption, e.g.,\rCheckMate, IsoMate, Cidetrak'], dtype='object')
# Index(['MODERATE to HIGH-RISK PESTICIDES, NO RESTRICTIONS BEYOND THOSE ON THE PRODUCT LABEL\r1.These pesticides may be used to the full extent of the pesticide label.  Moderate to high risks to environmental and human health are present.\r2.Use only after systematic scouting or weather monitoring and science-based thresholds, or according to previous history where thresholds are\rnot available.\r3.Pesticides included are not a guarantee of efficacy.  Some products will not be as effective as other products against specific target pests.',
#        'Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2'],
#       dtype='object')
# Index(['MODERATE to HIGH-RISKPESTICIDES, NO RESTRICTIONS BEYOND THOSE ON THE PRODUCT LABEL',
#        'Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2'],
#       dtype='object')
# Index(['MODERATE to HIGH-RISKPESTICIDES, NO RESTRICTIONS BEYOND THOSE ON THE PRODUCT LABEL',
#        'Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2'],
#       dtype='object')
# Index(['Lorsban', 'Lorsba'], dtype='object')
# Index(['Ceyva', 'Ceyv'], dtype='object')
# Index(['DO NOT USE', 'Unnamed: 0', 'Unnamed: 1'], dtype='object')
# Index(['DO NOT USE', 'Unnamed: 0', 'Unnamed: 1'], dtype='object')

# %%
for df in dfs_to_keep:
    try:
        results+=df['Unnamed: 0'].tolist()
    except:
        print (df)
# Out:
# Empty DataFrame
# Columns: [Miravis, Miravi]
# Index: []
# Empty DataFrame
# Columns: [Pydiflumetofen, Pydiflumetofe]
# Index: []
#   toxic to algae, aquatic\rinvertebrates and fish  toxic to algae, aquati
# 0                          invertebrates and fish                     NaN
#   Apply before apple-scab\rinfections to delay resistance.  \
# 0                     infections to delay resistance
#
#    Apply before apple-sca
# 0                     NaN

# %%
results.append('pydiflumetofen' )

# %%
to_print=[r for r in results if str(r) not in ['nan', 'Do not use wher',
 'resistance is known', 'Active Ingredient']]

# %%
with open('trueEarth_restricted.txt', 'w+') as file:
    print('\n'.join(to_print), file=file)

# %%
[x for y in dfs for x in y][0]
# Out:
#   USE WITH RESTRICTIONS (MODERATE to HIGH-RISK PESTICIDES), RESTRICTIONS WHICH EXCEED THE PRODUCT LABEL  \
# 0                                         Trade Name
# 1                             Insect/Mite Management
# 2                                     Neonicotinoids
# 3                                             Actara
# 4                                             Assail
# 5                                              Belay
# 6                        Admire Pro,\rAlias, Montana
# 7                                 Disease Management
# 8                           Agri-Mycin 17,\rFireWall
# 9                                            Kasumin
#
#              Unnamed: 0                                         Unnamed: 1  \
# 0     Active Ingredient                                           Concerns
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3          thiamethoxam  toxic to wildlife, highly toxic to\raquatic in...
# 4           acetamiprid  toxic to wildlife, toxic to bees, may\rresult ...
# 5          clothianidin  toxic to aquatic invertebrates,\rhighly toxic ...
# 6          imidacloprid  toxic to aquatic invertebrates, toxic\rto bees...
# 7                   NaN                                                NaN
# 8  streptomycin sulfate                                                NaN
# 9           kasugamycin                                                NaN
#
#                                           Unnamed: 2  \
# 0                              Truearth Restrictions
# 1                                                NaN
# 2                                                NaN
# 3  1.Do not apply until after bloom.\r2.Do not ex...
# 4  Do not expose more than one\rgeneration of the...
# 5  1.Do not apply until after bloom.\r2.Do not ex...
# 6  1.Do not apply until after bloom.\r2.Do not ex...
# 7                                                NaN
# 8  After bloom, apply only\rfollowing hail or win...
# 9  After bloom, apply only\rfollowing hail or win...
#
#                                           Unnamed: 3
# 0                                      Best Practice
# 1                                                NaN
# 2                                                NaN
# 3  These are IRAC 4A\rneonicotinoids.  Rotation\r...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  Apply only for fire blight\raccording to a wea...
# 9  Apply only for fire blight\raccording to a wea...

# %%
results=[]
i=0
for n, df in enumerate([x for y in dfs for x in y]):
    try:
        results+=df['Unnamed: 0'].tolist()
    except:
        print(df)
# Out:
# Empty DataFrame
# Columns: [Miravis, Miravi]
# Index: []
# Empty DataFrame
# Columns: [Pydiflumetofen, Pydiflumetofe]
# Index: []
#   toxic to algae, aquatic\rinvertebrates and fish  toxic to algae, aquati
# 0                          invertebrates and fish                     NaN
#   Apply before apple-scab\rinfections to delay resistance.  \
# 0                     infections to delay resistance
#
#    Apply before apple-sca
# 0                     NaN

# %%
results
# Out:
# ['Active Ingredient',
#  nan,
#  nan,
#  'thiamethoxam',
#  'acetamiprid',
#  'clothianidin',
#  'imidacloprid',
#  nan,
#  'streptomycin sulfate',
#  'kasugamycin',
#  'Active Ingredient',
#  nan,
#  'copper hydroxide,\rcopper oxychloride',
#  'copper hydroxide',
#  nan,
#  'benzovindiflupyr',
#  'penthiopyrad',
#  'fluopyram,\rtrifloxystrobin',
#  'fluxapyroxad,\rpyraclostrobin',
#  'Miravi',
#  'infections to delay resistance',
#  'Active Ingredient',
#  nan,
#  nan,
#  'cyprodinil,\rdifenoconazole',
#  'fenarimol',
#  'triflumizole',
#  'myclobutanil',
#  'flutriafol',
#  'Active Ingredient',
#  nan,
#  'paraquat dichloride',
#  'clethodim',
#  'terbacil',
#  '2,4-D',
#  nan,
#  'diphenylamine',
#  'ethephon',
#  'carbaryl']

# %%
[r for r in results if str(r)!= 'nan' and str(r)!='Active Ingredient']
# Out:
# ['thiamethoxam',
#  'acetamiprid',
#  'clothianidin',
#  'imidacloprid',
#  'streptomycin sulfate',
#  'kasugamycin',
#  'copper hydroxide,\rcopper oxychloride',
#  'copper hydroxide',
#  'benzovindiflupyr',
#  'penthiopyrad',
#  'fluopyram,\rtrifloxystrobin',
#  'fluxapyroxad,\rpyraclostrobin',
#  'Miravi',
#  'infections to delay resistance',
#  'cyprodinil,\rdifenoconazole',
#  'fenarimol',
#  'triflumizole',
#  'myclobutanil',
#  'flutriafol',
#  'paraquat dichloride',
#  'clethodim',
#  'terbacil',
#  '2,4-D',
#  'diphenylamine',
#  'ethephon',
#  'carbaryl']

# %%
banned_pesticides=dfs[0][dfs[0].columns[0]].to_list()+['Lead Arsenate']+dfs[1]['Lead Arsenate'].to_list()

# %%
banned_pesticides
# Out:
# ['INGREDIENTES ACTIVOS',
#  '1,2-Dibromo-3-Chloropropane (DBCP)',
#  '1,2-Dibromoethane Ethylene Dibromide (EDB)',
#  '1,2-Dichloroethane Ethylene Dichloride (EDC)',
#  '2,3,4,5-Bis (2-Butylene) Tetrahydro-2-Furaldehyde',
#  '2,4,5-Trichlorophenol',
#  '2,4,5-Trichlorophenoxyacetic Acid [2,4,5-T]',
#  '2,4-D, Isooctyl Ester',
#  '4,6-Dinitro-O-Cresol',
#  'Alachlor',
#  'Aldicarb',
#  'Aldrin',
#  'Arsenic Oxide (3)',
#  'Azinphos Methyl',
#  'Azodrin',
#  'Benomylo: Formulación En Polvo Seco Con Combinación De\rBenomylo > 7% + Carbofurano >10% + Thiram >15%',
#  'Binapacryl',
#  'Bromoxynil Butyrate',
#  'Cadmium Compounds',
#  'Calcium Arsenate',
#  'Captafol',
#  'Carbofuran',
#  'Carbon Tetrachloride',
#  'Chloranil',
#  'Chlordane',
#  'Chlordecone (Kepone)',
#  'Chlordimeform',
#  'Chlorobenzilate',
#  'Chloromethoxypropylmercuric Acetate [CPMA]',
#  'Copper Arsenate',
#  'DDD (Dichloro Diphenyl Dichloroethane)',
#  'DDT (Dichloro Diphenyl Trichloroethane)',
#  'Di(Phenylmercury)Dodecenylsuccinate [PMDS]',
#  'Dicofol',
#  'Dieldrin',
#  'Dinitrobutyl Phenol',
#  'Dinitro-Ortho-Cresol (DNOC)',
#  'Dinoseb, Its Acetate And Salts',
#  'Endosulfan',
#  'Endrin',
#  'EPN (Ethyl P-Nitrophenyl Thio-Phosphonate)',
#  'Ethyl Hexyleneglycol [6-12]',
#  'Ethylene Dichloride',
#  'Ethylene Oxide',
#  'Fluoroacetamide',
#  'Fonofos',
#  'Fosfamidon Formulación Líquida Soluble',
#  'Gamma-Lindane',
#  'Heptachlor Y Epóxido De Heptacloro',
#  'Hexachlorobenzene (HCB)',
#  'Hexachlorociclohexane (HCH)',
#  'Inorganic Mercury Compounds',
#  'Isobenzan',
#  'Lead Arsenate',
#  'Leptophos',
#  'Lindano (1,2,3,4,5,6-Hexachlorocyclohexane (Mixture Of Isomers))',
#  'Maneb',
#  'Melipax',
#  'Mercuric Oxide',
#  'Mercurous Chloride (Calomel)',
#  'Methamidofos: Formulación Líquido Soluble Que Sobrepase 600 Gr/Lt\rDe Ingrediente Activo',
#  'Methyl Bromide',
#  'Methyl Parathion',
#  'Methyl Parathion:  CE con mas de 19.5% de ingrediente activo',
#  'Methyl Parathion : Formulación Polvo con mas de 1.5% de ingrediente\ractivo',
#  'Mevinphos',
#  'Mirex (Dodecacloro)',
#  'Monocrotophos',
#  'Nitrofen (Tok)',
#  'Ompa (Octamethylpyrophosphoramide)',
#  'Paraquat',
#  'Parathion',
#  'Pentachlorophenol (PCP)',
#  'Phenylmercuric Oleate [PMO]',
#  'Phenylmercury Acetate [PMA]',
#  'Potassium 2,4,5-Trichlorophenate (2,4,5 TCP)',
#  'Phosphamidon (liquido soluble con más de 1000 gr ia/lt)',
#  'Pyriminil',
#  'Safrole',
#  'Silvex (2,4,5-Trichlorophenoxy P Acid )',
#  'Sodium Arsenate',
#  'Sodium Arsenite',
#  'TDE (Triethylene Glycol Diglycidyl Ether)',
#  'Terpene Polychlorinates [Strobane]',
#  'Thallium Sulfate',
#  'Toxaphene (Camphechlor)',
#  'Tributyltin Compounds',
#  'Vinyl Chloride',
#  'Zineb']

# %%
with open('FlorVerde_banned_pesticides.txt', 'w+') as file:
    print('\n'.join(banned_pesticides), file=file)

# %%
pdf_path=r"C:\Users\benja\Documents\UVM\Dissertation_Docs\Cert_standards\SIP_VineyardWinery_Standards_2018.pdf"
dfs=tabula.read_pdf(pdf_path, pages='all')
# Out:
# Got stderr: Oct 19, 2020 5:00:14 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Oct 19, 2020 5:00:14 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Oct 19, 2020 5:00:15 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 447 fonts

# %%
banned_ingreds=['(S)-CYPERMETHRIN']+dfs[-1]['(S)-CYPERMETHRIN'].tolist()

# %%
banned_ingreds
# Out:
# ['(S)-CYPERMETHRIN',
#  '2,4-D',
#  '2,4-D, DIMETHYLAMINE SALT',
#  '4-AMINOPYRIDINE',
#  'ABAMECTIN',
#  'ACEPHATE X',
#  'ALUMINUM PHOSPHIDE',
#  'BENTAZON, SODIUM SALT',
#  'BETA-CYFLUTHRIN',
#  'BIFENTHRIN',
#  'CAPTAN',
#  'CARBARYL X',
#  'CHLOROPICRIN',
#  'CHLORPYRIFOS X',
#  'CYFLUTHRIN',
#  'DIAZINON X',
#  'DIMETHOATE X',
#  'DIPHACINONE',
#  'DIURON',
#  'ENDOSULFAN',
#  'ETHEPHON X',
#  'FENBUTATIN-OXIDE',
#  'FENPROPATHRIN',
#  'HYDROGEN CYANAMIDE',
#  'MAGNESIUM PHOSPHIDE',
#  'MALATHION X',
#  'MANCOZEB',
#  'META-CRESOL',
#  'METHIOCARB X',
#  'METHOMYL X',
#  'METHYL BROMIDE',
#  'NALED X',
#  'NORFLURAZON',
#  'OXYDEMETON-METHYL X',
#  'PARAQUAT DICHLORIDE',
#  'PHOSMET X',
#  'POTASSIUM N-',
#  'X METHYLDITHIOCARBAMATE',
#  'PROPARGITE',
#  'PROPYLENE OXIDE',
#  'PROPYZAMIDE',
#  'SIMAZINE',
#  'SULFUR DIOXIDE',
#  'SULFURYL FLUORIDE',
#  'TRIFLURALIN',
#  'ZINC PHOSPHIDE']

# %%
with open('SIP_banned_pesticides.txt', 'w+') as file:
    print('\n'.join(banned_ingreds), file=file)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\benja'

# %%
os.
